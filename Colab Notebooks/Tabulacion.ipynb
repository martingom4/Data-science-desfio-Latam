# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/Data science/Python/Apoyodesafio/asfd.csv')
df1.head()
# Out:
#      Marca temporal              Edad     Género  \
# 0  06/29/2024 20:10        20-29 años   Femenino
# 1  06/29/2024 20:11  Menos de 20 años       Otro
# 2  06/29/2024 20:20        30-39 años  Masculino
# 3  06/29/2024 20:21        20-29 años  Masculino
# 4  06/29/2024 20:25        20-29 años   Femenino
#
#                                      Nivel Educativo  \
# 0                      Educación superior (pregrado)
# 1                                 Educación primaria
# 2  Educación primaria, Educación secundaria, Educ...
# 3                     Educación superior (postgrado)
# 4                      Educación superior (pregrado)
#
#                           Sector Laboral  \
# 0                               Comercio
# 1                  Servicios financieros
# 2               Administración, Comercio
# 3        Comercio, Servicios financieros
# 4  Construcción e Industrias Extractivas
#
#   ¿Cuántos años de experiencia tiene en su sector laboral actual?   \
# ...

# %%
 Tabulacion_edad = df1.value_counts('Edad')
print(Tabulacion_edad)
# Out:
# Edad
# 20-29 años          13
# Menos de 20 años     6
# 30-39 años           3
# 40-50 años o más     1
# Name: count, dtype: int64

# %%
Tabulacion_genero = df1.value_counts('Género')
print(Tabulacion_genero)
# Out:
# Género
# Masculino    12
# Femenino     10
# Otro          1
# Name: count, dtype: int64
